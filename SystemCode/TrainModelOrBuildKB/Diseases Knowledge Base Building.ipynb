# %%
# pip install sparqlwrapper

# %%
import pandas as pd
from pandas.io.json import json_normalize
import sqlite3

import re

import sys
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
def get_results(endpoint_url, query):
    user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
    # TODO adjust user agent; see https://w.wiki/CX6
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    result = sparql.query().convert()
    return json_normalize(result["results"]["bindings"])

# %%
### Query all diseases with Disease Ontology ID and get their alternative names if available


endpoint_url = "https://query.wikidata.org/sparql"

query = """SELECT ?name ?doidLabel ?nameLabel ?aliasLabel WHERE { 
  # ?name wdt:P699 ?doidLabel
        OPTIONAL {
            # ?name skos:altLabel ?aliasLabel .
            FILTER (lang(?aliasLabel)='en')
            }
    SERVICE wikibase:label { bd:serviceParam wikibase:language "en" }
}"""

results = get_results(endpoint_url, query)
results
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_13140\4046432563.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   return json_normalize(result["results"]["bindings"])
#       name.type                                name.value aliasLabel.xml:lang  \
# 0           uri     http://www.wikidata.org/entity/Q72000                  en
# 1           uri     http://www.wikidata.org/entity/Q72000                  en
# 2           uri     http://www.wikidata.org/entity/Q72000                  en
# 3           uri     http://www.wikidata.org/entity/Q72000                  en
# 4           uri     http://www.wikidata.org/entity/Q73518                  en
# ...         ...                                       ...                 ...
# 50108       uri  http://www.wikidata.org/entity/Q19001364                  en
# 50109       uri  http://www.wikidata.org/entity/Q28024560                  en
# 50110       uri  http://www.wikidata.org/entity/Q28024560                  en
# 50111       uri  http://www.wikidata.org/entity/Q28024561                  en
# 50112       uri  http://www.wikidata.org/entity/Q28024561                  en
#
#       aliasLabel.type                       aliasLabel.value doidLabel.type  \
# 0             literal                      Lemierre syndrome        literal
# 1             literal                      acute sore throat        literal
# 2             literal                  human necrobacillosis        literal
# 3             literal                     postanginal sepsis        literal
# 4             literal  non-bacterial thrombotic endocarditis        literal
# ...               ...                                    ...            ...
# 50108         literal           EPISODIC ATAXIA, TYPE 7; EA7        literal
# 50109         literal                                  CMD1K        literal
# 50110         literal         dilated cardiomyopathy type 1K        literal
# 50111         literal           CARDIOMYOPATHY, DILATED, 1JJ        literal
# 50112         literal   CARDIOMYOPATHY, DILATED, 1JJ; CMD1JJ        literal
#
#       doidLabel.value nameLabel.xml:lang nameLabel.type  \
# 0          DOID:11337                 en        literal
# 1          DOID:11337                 en        literal
# 2          DOID:11337                 en        literal
# 3          DOID:11337                 en        literal
# 4        DOID:0060068                 en        literal
# ...               ...                ...            ...
# 50108    DOID:0050995                 en        literal
# 50109    DOID:0110437                 en        literal
# 50110    DOID:0110437                 en        literal
# 50111    DOID:0110438                 en        literal
# 50112    DOID:0110438                 en        literal
#
#                   nameLabel.value
# 0             Lemierre's syndrome
# 1             Lemierre's syndrome
# 2             Lemierre's syndrome
# 3             Lemierre's syndrome
# 4           marantic endocarditis
# ...                           ...
# 50108      episodic ataxia type 7
# 50109   dilated cardiomyopathy 1K
# 50110   dilated cardiomyopathy 1K
# 50111  dilated cardiomyopathy 1JJ
# 50112  dilated cardiomyopathy 1JJ
#
# [50113 rows x 10 columns]

# %%
df_disease = results[["doidLabel.value","nameLabel.value","aliasLabel.value"]]
df_disease = df_disease.rename(columns = lambda col: col.replace("Label.value", ""))
df_disease.head()
# Out:
#            doid                   name                                  alias
# 0    DOID:11337    Lemierre's syndrome                      Lemierre syndrome
# 1    DOID:11337    Lemierre's syndrome                      acute sore throat
# 2    DOID:11337    Lemierre's syndrome                  human necrobacillosis
# 3    DOID:11337    Lemierre's syndrome                     postanginal sepsis
# 4  DOID:0060068  marantic endocarditis  non-bacterial thrombotic endocarditis

# %%
df_disease = df_disease[(df_disease['doid'].str.contains("DOID"))]
df_disease.sort_values('doid')
# Out:
#                doid                       name  \
# 48937  DOID:0001816               angiosarcoma
# 7341   DOID:0002116                  pterygium
# 16144  DOID:0014667          metabolic disease
# 16143  DOID:0014667          metabolic disease
# 16142  DOID:0014667          metabolic disease
# ...             ...                        ...
# 1137       DOID:999               eosinophilia
# 4225      DOID:9993               hypoglycemia
# 21067     DOID:9997  peripartum cardiomyopathy
# 21066     DOID:9997  peripartum cardiomyopathy
# 21065     DOID:9997  peripartum cardiomyopathy
#
#                                       alias
# 48937                                   NaN
# 7341                           Surfer's Eye
# 16144                     metabolic illness
# 16143                    metabolic diseases
# 16142         disorder of metabolic process
# ...                                     ...
# 1137                Eosinophil count raised
# 4225                          hypoglycaemia
# 21067  postpartum peripartum cardiomyopathy
# 21066  antepartum peripartum cardiomyopathy
# 21065             Postpartum cardiomyopathy
#
# [50077 rows x 3 columns]

# %%
### Query all diseases with Disease Ontology ID and get their health specialty type ( for identification of infectious disease)


endpoint_url = "https://query.wikidata.org/sparql"

query2 =  """
SELECT ?doidLabel ?diseaseLabel ?specialty_typeLabel WHERE { 
  # ?disease wdt:P699 ?doidLabel .
    OPTIONAL { 
        # ?disease wdt:P1995 ?specialty_type .
    }  
    SERVICE wikibase:label { bd:serviceParam wikibase:language "en" }
}
"""

results2 = get_results(endpoint_url, query2)
results2
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_13140\4046432563.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   return json_normalize(result["results"]["bindings"])
#       doidLabel.type doidLabel.value diseaseLabel.xml:lang diseaseLabel.type  \
# 0            literal       DOID:2377                    en           literal
# 1            literal        DOID:437                    en           literal
# 2            literal        DOID:150                    en           literal
# 3            literal        DOID:150                    en           literal
# 4            literal      DOID:14351                    en           literal
# ...              ...             ...                   ...               ...
# 11637        literal    DOID:0080045                    en           literal
# 11638        literal       DOID:4321                    en           literal
# 11639        literal    DOID:0060740                    en           literal
# 11640        literal    DOID:0111875                    en           literal
# 11641        literal    DOID:0080119                    en           literal
#
#                                       diseaseLabel.value  \
# 0                                     multiple sclerosis
# 1                                      myasthenia gravis
# 2                                        mental disorder
# 3                                        mental disorder
# 4                         Riedel's fibrosing thyroiditis
# ...                                                  ...
# 11637                                   Kniest dysplasia
# 11638                               large-cell acanthoma
# 11639                methylmalonyl-CoA mutase deficiency
# 11640  microphthalmia–dermal aplasia–sclerocornea syn...
# 11641             mitochondrial DNA depletion syndrome 1
#
#       specialty_typeLabel.xml:lang specialty_typeLabel.type  \
# 0                               en                  literal
# 1                               en                  literal
# 2                               en                  literal
# 3                               en                  literal
# 4                               en                  literal
# ...                            ...                      ...
# 11637                           en                  literal
# 11638                          NaN                      NaN
# 11639                          NaN                      NaN
# 11640                          NaN                      NaN
# 11641                          NaN                      NaN
#
#       specialty_typeLabel.value
# 0                     neurology
# 1                     neurology
# 2                    psychiatry
# 3           clinical psychology
# 4                 endocrinology
# ...                         ...
# 11637          medical genetics
# 11638                       NaN
# 11639                       NaN
# 11640                       NaN
# 11641                       NaN
#
# [11642 rows x 8 columns]

# %%
df_infect = results2[["doidLabel.value", "diseaseLabel.value", "specialty_typeLabel.value"]]
df_infect = df_infect.rename(columns = lambda col: col.replace("Label.value", ""))
df_infect.head()
# Out:
#          doid                         disease       specialty_type
# 0   DOID:2377              multiple sclerosis            neurology
# 1    DOID:437               myasthenia gravis            neurology
# 2    DOID:150                 mental disorder           psychiatry
# 3    DOID:150                 mental disorder  clinical psychology
# 4  DOID:14351  Riedel's fibrosing thyroiditis        endocrinology

# %%
df_infect['specialty_type'].unique()
# Out:
# array(['neurology', 'psychiatry', 'clinical psychology', 'endocrinology',
#        'pulmonology', 'infectious diseases', 'immunology', 'psychology',
#        'ophthalmology', 'gastroenterology', 'cardiology', 'optometry',
#        'orthopedics', 'pediatrics', 'medical genetics', 'hematology',
#        'rheumatology', 'dermatology', 'oncology', 'military medicine',
#        nan, 'urology', 'obstetrics', 'psychomotor education',
#        'oral surgery', 'gynaecology', 'psychotherapy', 'otolaryngology',
#        'angiology', 'nephrology', 'hepatology', 'dentistry',
#        'Medicina fisica y rehabilitacion',
#        'physical medicine and rehabilitation', 'helminthologist',
#        'maternal-fetal medicine', 'neonatology', 'oral medicine',
#        'narcology', 'addiction medicine', 'emergency medicine',
#        'obstetrics and gynaecology', 'oral and maxillofacial surgery',
#        'nutrition', 'gynecologic oncology', 'phlebology', 'neurosurgery',
#        'allergology', 'endocrine surgery', 'diabetology',
#        'internal medicine', 'family medicine', 'neuropsychology',
#        'neuropsychiatry', 'intensive care medicine', 'pathology',
#        'sports medicine', 'general surgery', 'epileptology',
#        'digestive system surgery', 'vascular surgery', 'ophthalmologist',
#        'thoracic surgery', 'tropical medicine', 'helminthology',
#        'periodontology', 'neuromuscular medicine', 'parasitology',
#        'poisoning', 'environmental medicine',
#        'child and adolescent psychiatry', 'veterinary medicine',
#        'sleep medicine', 'neuropathology', 'endodontics',
#        'space medicine', 'Neurooncology', 'speech-language pathology',
#        'reproductive medicine', 'surgery', 'genetics',
#        'occupational therapy', 'metabolic disease',
#        'medical parasitology', 'cardiac surgery', 'language',
#        'metabolic syndrome', 'occupational medicine', 'diving medicine',
#        'Oral and maxillofacial surgery', 'andrology', 'Neuro-Oncology',
#        'pediatrician', 'podiatry', 'interventional neuroradiology',
#        'Transfusion Medicine', 'immunohaematology', 'sexology',
#        'reproductive endocrinology and infertility', 'strabology',
#        'orthopedic surgery', 'endocrine oncology', 'clinical nutrition',
#        'circulatory system', 'mastology', 'virology', 'epidemiology',
#        'infectious disease', 'microbiology', 'rhinology', 'midwifery',
#        'plastic surgery', 'pediatric surgery',
#        'pediatric cardiac surgery', 'medical emergency', 'Nephrologie',
#        'addiction psychiatry'], dtype=object)

# %%
# create indicator whether disease specialty contains infect
df_infect['infectious']= df_infect["specialty_type"].str.contains(r'infect')*1

# %%
# clean up doid column
df_infect = df_infect[(df_infect['doid'].str.contains("DOID"))]
# for each doid, identify if disease is infectious or not
df_infect = df_infect.sort_values(['doid','infectious'], ascending=False).groupby('doid').head(1)
df_infect
# Out:
#                doid                    disease       specialty_type infectious
# 9840      DOID:9997  peripartum cardiomyopathy           cardiology          0
# 6742      DOID:9993               hypoglycemia        endocrinology          0
# 11154      DOID:999               eosinophilia           hematology          0
# 9410      DOID:9988     tertiary neurosyphilis  infectious diseases          1
# 6319      DOID:9987              orbit sarcoma                  NaN        NaN
# ...             ...                        ...                  ...        ...
# 426    DOID:0040002     salicylate sensitivity                  NaN        NaN
# 5604   DOID:0040001             shrimp allergy                  NaN        NaN
# 4309   DOID:0014667          metabolic disease        endocrinology          0
# 961    DOID:0002116                  pterygium        ophthalmology          0
# 5308   DOID:0001816               angiosarcoma             oncology          0
#
# [10598 rows x 4 columns]

# %%
# Merge disease alt names with indicator of whether disease is infectious or not
disease_kb = df_disease.merge(df_infect[["doid","infectious"]], how='left', on="doid")
disease_kb
# Out:
#                doid                        name  \
# 0        DOID:11337         Lemierre's syndrome
# 1        DOID:11337         Lemierre's syndrome
# 2        DOID:11337         Lemierre's syndrome
# 3        DOID:11337         Lemierre's syndrome
# 4      DOID:0060068       marantic endocarditis
# ...             ...                         ...
# 50072  DOID:0050995      episodic ataxia type 7
# 50073  DOID:0110437   dilated cardiomyopathy 1K
# 50074  DOID:0110437   dilated cardiomyopathy 1K
# 50075  DOID:0110438  dilated cardiomyopathy 1JJ
# 50076  DOID:0110438  dilated cardiomyopathy 1JJ
#
#                                        alias infectious
# 0                          Lemierre syndrome          1
# 1                          acute sore throat          1
# 2                      human necrobacillosis          1
# 3                         postanginal sepsis          1
# 4      non-bacterial thrombotic endocarditis          0
# ...                                      ...        ...
# 50072           EPISODIC ATAXIA, TYPE 7; EA7        NaN
# 50073                                  CMD1K          0
# 50074         dilated cardiomyopathy type 1K          0
# 50075           CARDIOMYOPATHY, DILATED, 1JJ          0
# 50076   CARDIOMYOPATHY, DILATED, 1JJ; CMD1JJ          0
#
# [50077 rows x 4 columns]

# %%
# Create sqlite database and cursor
conn = sqlite3.connect('disease_kb.db')
c = conn.cursor()
# Create the table
c.execute("""CREATE TABLE IF NOT EXISTS disease (
            doid ID,
            name text,
            alias text,
            infectious real
            )""")
conn.commit()

disease_kb.to_sql('disease', conn, if_exists='append', index=False)

test = conn.execute('SELECT * from disease')
print(test)
# Out:
# <sqlite3.Cursor object at 0x0000020BDC094260>
